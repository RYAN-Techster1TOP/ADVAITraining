# %% [markdown]
# <a href="https://colab.research.google.com/github/RYAN-Techster1TOP/ADVAITraining/blob/main/Speech_to_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Create Text from Audio using Whisper Model***
